# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("ExportRiffleSamplesData_ALL.csv")
df
# Out:
#                                       ParkName ParkCode  Season  \
# 0     Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 1     Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 2     Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 3     Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 4     Ozark National Scenic Riverways - RIVERS     OZAR    2005
# ...                                        ...      ...     ...
# 3350  Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 3351  Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 3352  Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 3353  Ozark National Scenic Riverways - RIVERS     OZAR    2005
# 3354  Ozark National Scenic Riverways - RIVERS     OZAR    2005
#
#           LocationID              EventID  RiffleNo Replicate  Width  Depth  \
# 0     OZARRMINVEJM02  OZARRMINVE2006JAN12         1         L   22.0   18.0
# ...

# %%
df.dtypes
# Out:
# ParkName          object
# ParkCode          object
# Season             int64
# LocationID        object
# EventID           object
# RiffleNo           int64
# Replicate         object
# Width            float64
# Depth            float64
# Velocity         float64
# Substrate        float64
# Substrate_mm     float64
# Embeddedness     float64
# Embeddedness%    float64
# Vegetation       float64
# Vegetation%      float64
# Algae            float64
# Algae%           float64
# Periphyton       float64
# Periphyton%      float64
# Deposition       float64
# Deposition%      float64
# Organics         float64
# Organics%        float64
# DETimeStamp       object
# dtype: object

# %%
sorted(df['ParkName'].unique())
# Out:
# ['Buffalo National River',
#  'Effigy Mounds National Monument',
#  'George Washington Carver National Monument',
#  'Herbert Hoover National Historic Site',
#  'Hot Springs National Park',
#  'Ozark National Scenic Riverways - RIVERS',
#  'Pea Ridge National Military Park',
#  'Pipestone National Monument',
#  'Tallgrass Prairie National Preserve',
#  'Wilsons Creek National Battlefield']

# %%
frequency = df['ParkName'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
df['ParkCode'] = df['ParkCode'].astype(str)

# %%
sorted(df['ParkCode'].unique())
# Out:
# ['BUFF',
#  'EFMO',
#  'GWCA',
#  'HEHO',
#  'HOSP',
#  'OZAR',
#  'PERI',
#  'PIPE',
#  'TAPR',
#  'WICR']

# %%
frequency = df['ParkCode'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
sorted(df['Season'].unique())
# Out:
# [np.int64(2005),
#  np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2012),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018),
#  np.int64(2019),
#  np.int64(2020),
#  np.int64(2021),
#  np.int64(2022),
#  np.int64(2023),
#  np.int64(2024)]

# %%
plt.hist(df['Season'], bins=5, edgecolor='black')
plt.title('Histogram of Season')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['LocationID'].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT01',
#  'BUFFRMINVEBT03',
#  'BUFFRMINVEBT04',
#  'BUFFRMINVEBT05',
#  'BUFFRMINVEBT06',
#  'BUFFRMINVEBT07',
#  'BUFFRMINVEBT08',
#  'BUFFRMINVEBT09',
#  'BUFFRMINVEBT10',
#  'BUFFRMINVEBT11',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT14',
#  'BUFFRMINVEBT15',
#  'BUFFRMINVEBT16',
#  'BUFFRMINVEBT17',
#  'BUFFRMINVEBT19',
#  'BUFFRMINVEBT20',
#  'BUFFRMINVEBT22',
#  'BUFFRMINVEBT23',
#  'BUFFRMINVEBT24',
#  'BUFFRMINVEBT25',
#  'BUFFRMINVEBT27',
#  'BUFFRMINVEBT30',
#  'BUFFRMINVEBT31',
#  'BUFFRMINVEBT33',
#  'EFMOAqubug01',
#  'GWCAAquBug01',
#  'GWCAAquBug02',
#  'GWCAAquBug03',
#  'HEHOAqubug01',
#  'HOSPAqubug01',
#  'HOSPAqubug02',
#  'OZARRMINVECM01',
#  'OZARRMINVECM02',
#  'OZARRMINVECM03',
#  'OZARRMINVECM04',
#  'OZARRMINVECM05',
#  'OZARRMINVECM06',
#  'OZARRMINVECT01',
#  'OZARRMINVECT02',
#  'OZARRMINVECT03',
#  'OZARRMINVECT04',
# ...

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMINVE2005DEC01',
#  'BUFFRMINVE2005DEC14',
#  'BUFFRMINVE2005DEC20',
#  'BUFFRMINVE2005NOV29',
#  'BUFFRMINVE2005NOV30',
#  'BUFFRMINVE2007Dec03',
#  'BUFFRMINVE2007Dec04',
#  'BUFFRMINVE2007FEB09',
#  'BUFFRMINVE2007FEB20',
#  'BUFFRMINVE2007FEB21',
#  'BUFFRMINVE2007FEB22',
#  'BUFFRMINVE2007JAN04',
#  'BUFFRMINVE2007JAN05',
#  'BUFFRMINVE2007JAN08',
#  'BUFFRMINVE2007JAN09',
#  'BUFFRMINVE2007Nov26',
#  'BUFFRMINVE2007Nov27',
#  'BUFFRMINVE2007Nov28',
#  'BUFFRMINVE2007Nov29',
#  'BUFFRMINVE2007Nov30',
#  'BUFFRMINVE2008Dec02',
#  'BUFFRMINVE2008Dec03',
#  'BUFFRMINVE2008Dec04',
#  'BUFFRMINVE2008Dec05',
#  'BUFFRMINVE2008Dec10',
#  'BUFFRMINVE2008Dec11',
#  'BUFFRMINVE2008Jan22',
#  'BUFFRMINVE2008Jan23',
#  'BUFFRMINVE2009Dec07',
#  'BUFFRMINVE2009Dec08',
#  'BUFFRMINVE2009Dec14',
#  'BUFFRMINVE2009Dec15',
#  'BUFFRMINVE2009Dec16',
#  'BUFFRMINVE2009Feb18',
#  'BUFFRMINVE2009Jan08',
#  'BUFFRMINVE2010Dec01',
#  'BUFFRMINVE2010Jan11',
#  'BUFFRMINVE2010Jan12',
# ...

# %%
sorted(df['RiffleNo'].unique())
# Out:
# [np.int64(1), np.int64(2), np.int64(3)]

# %%
plt.hist(df['RiffleNo'], bins=10, edgecolor='black')
plt.title('Histogram of RiffleNo')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['Replicate'].unique())
# Out:
# ['L', 'M', 'R']

# %%
frequency = df['Replicate'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
df['filtered_Width'] = df.loc[df['Width'] >= 0, 'Width']

# %%
plt.hist(df['filtered_Width'], bins=5, edgecolor='black')
plt.title('Histogram of Width')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Depth'] = df.loc[df['Depth'] >= 0, 'Depth']

# %%
plt.hist(df['filtered_Depth'], bins=5, edgecolor='black')
plt.title('Histogram of Depth')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Velocity'] = df.loc[df['Velocity'] >= 0, 'Velocity']

# %%
plt.hist(df['filtered_Velocity'], bins=5, edgecolor='black')
plt.title('Histogram of Velocity')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Substrate'], bins=5, edgecolor='black')
plt.title('Histogram of Substrate')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Substrate_mm'], bins=5, edgecolor='black')
plt.title('Histogram of Substrate_mm')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Substrate_mm'] = df.loc[(df['Substrate_mm'] > 0) & (df['Substrate_mm'] < 2000), 'Substrate_mm']

# %%
plt.hist(df['filtered_Substrate_mm'], bins=50, edgecolor='black')
plt.title('Histogram of Substrate_mm')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Substrate_mm'] = df.loc[(df['Substrate_mm'] > 2000), 'Substrate_mm']

# %%
plt.hist(df['filtered_Substrate_mm'], bins=50, edgecolor='black')
plt.title('Histogram of Substrate_mm')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Embeddedness'], bins=50, edgecolor='black')
plt.title('Histogram of Embeddedness')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Embeddedness%'], bins=50, edgecolor='black')
plt.title('Histogram of Embeddedness%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Vegetation'], bins=50, edgecolor='black')
plt.title('Histogram of Vegetation')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Vegetation%'], bins=50, edgecolor='black')
plt.title('Histogram of Vegetation%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Algae'], bins=50, edgecolor='black')
plt.title('Histogram of Algae')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Algae%'], bins=50, edgecolor='black')
plt.title('Histogram of Algae%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Periphyton'], bins=50, edgecolor='black')
plt.title('Histogram of Periphyton')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Periphyton%'], bins=50, edgecolor='black')
plt.title('Histogram of Periphyton%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Deposition'] = df.loc[(df['Deposition'] > 0), 'Deposition']

# %%
plt.hist(df['filtered_Deposition'], bins=50, edgecolor='black')
plt.title('Histogram of Deposition')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Deposition%'] = df.loc[(df['Deposition%'] > 0), 'Deposition%']

# %%
plt.hist(df['filtered_Deposition%'], bins=50, edgecolor='black')
plt.title('Histogram of Deposition%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Organics'] = df.loc[(df['Organics'] > 0), 'Organics']

# %%
plt.hist(df['filtered_Organics'], bins=50, edgecolor='black')
plt.title('Histogram of Organics')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Organics%'] = df.loc[(df['Organics%'] > 0), 'Organics%']

# %%
plt.hist(df['filtered_Organics%'], bins=50, edgecolor='black')
plt.title('Histogram of Organics%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# Omitted DETimeStamp in the QC review
