# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("ExportDischargeDetailData_ALL.csv")
df
# Out:
#                                 ParkName ParkCode  Season      LocationID  \
# 0                 Buffalo National River     BUFF    2005  BUFFRMINVEBM03
# 1                 Buffalo National River     BUFF    2005  BUFFRMINVEBM03
# 2                 Buffalo National River     BUFF    2005  BUFFRMINVEBM03
# 3                 Buffalo National River     BUFF    2005  BUFFRMINVEBM03
# 4                 Buffalo National River     BUFF    2005  BUFFRMINVEBM03
# ...                                  ...      ...     ...             ...
# 3584  Wilsons Creek National Battlefield     WICR    2022    WICRAQUBUG04
# 3585  Wilsons Creek National Battlefield     WICR    2022    WICRAQUBUG04
# 3586  Wilsons Creek National Battlefield     WICR    2022    WICRAQUBUG04
# 3587  Wilsons Creek National Battlefield     WICR    2022    WICRAQUBUG04
# 3588  Wilsons Creek National Battlefield     WICR    2022    WICRAQUBUG04
#
#                   EventID   Units  DischargeNo  DistanceFromBank_m  Depth_cm  \
# 0     BUFFRMINVE2005NOV30  meters           13                 6.0        18
# 1     BUFFRMINVE2005NOV30  meters           14                 6.5        21
# 2     BUFFRMINVE2005NOV30  meters           15                 7.0        24
# 3     BUFFRMINVE2005NOV30  meters           16                 7.5        26
# 4     BUFFRMINVE2005NOV30  meters           17                 8.0        24
# ...                   ...     ...          ...                 ...       ...
# 3584  WICRAquBug2022Jun02  meters           16                 7.5        49
# 3585  WICRAquBug2022Jun02  meters           17                 8.0        63
# 3586  WICRAquBug2022Jun02  meters           18                 8.5        70
# 3587  WICRAquBug2022Jun02  meters           19                 9.0        60
# 3588  WICRAquBug2022Jun02  meters           20                 9.5        25
#
#       Velocity_ms Comments      DETimeStamp
# 0            0.41      NaN  10/5/2020 11:46
# 1            0.46      NaN  10/5/2020 11:46
# 2            0.60      NaN  10/5/2020 11:46
# 3            0.52      NaN  10/5/2020 11:46
# 4            0.39      NaN  10/5/2020 11:46
# ...           ...      ...              ...
# 3584         0.55      NaN  2/15/2023 16:20
# 3585         0.48      NaN  2/15/2023 16:20
# 3586         0.50      NaN  2/15/2023 16:20
# 3587         0.60      NaN  2/15/2023 16:20
# 3588         0.27      NaN  2/15/2023 16:20
#
# [3589 rows x 12 columns]

# %%
df.dtypes
# Out:
# ParkName               object
# ParkCode               object
# Season                  int64
# LocationID             object
# EventID                object
# Units                  object
# DischargeNo             int64
# DistanceFromBank_m    float64
# Depth_cm                int64
# Velocity_ms           float64
# Comments               object
# DETimeStamp            object
# dtype: object

# %%
sorted(df['ParkName'].unique())
# Out:
# ['Buffalo National River',
#  'Effigy Mounds National Monument',
#  'George Washington Carver National Monument',
#  'Herbert Hoover National Historic Site',
#  'Hot Springs National Park',
#  'Ozark National Scenic Riverways - RIVERS',
#  'Pea Ridge National Military Park',
#  'Pipestone National Monument',
#  'Tallgrass Prairie National Preserve',
#  'Wilsons Creek National Battlefield']

# %%
frequency = df['ParkName'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
sorted(df['ParkCode'].unique())
# Out:
# ['BUFF',
#  'EFMO',
#  'GWCA',
#  'HEHO',
#  'HOSP',
#  'OZAR',
#  'PERI',
#  'PIPE',
#  'TAPR',
#  'WICR']

# %%
frequency = df['ParkCode'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
sorted(df['Season'].unique())
# Out:
# [np.int64(2005),
#  np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2012),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018),
#  np.int64(2019),
#  np.int64(2020),
#  np.int64(2021),
#  np.int64(2022),
#  np.int64(2023),
#  np.int64(2024)]

# %%
plt.hist(df['Season'], bins=5, edgecolor='black')
plt.title('Histogram of Season')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['LocationID'].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT01',
#  'BUFFRMINVEBT03',
#  'BUFFRMINVEBT04',
#  'BUFFRMINVEBT05',
#  'BUFFRMINVEBT06',
#  'BUFFRMINVEBT07',
#  'BUFFRMINVEBT08',
#  'BUFFRMINVEBT09',
#  'BUFFRMINVEBT10',
#  'BUFFRMINVEBT11',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT14',
#  'BUFFRMINVEBT15',
#  'BUFFRMINVEBT16',
#  'BUFFRMINVEBT17',
#  'BUFFRMINVEBT19',
#  'BUFFRMINVEBT20',
#  'BUFFRMINVEBT22',
#  'BUFFRMINVEBT23',
#  'BUFFRMINVEBT24',
#  'BUFFRMINVEBT25',
#  'BUFFRMINVEBT27',
#  'BUFFRMINVEBT29',
#  'BUFFRMINVEBT30',
#  'BUFFRMINVEBT31',
#  'BUFFRMINVEBT33',
#  'EFMOAqubug01',
#  'GWCAAquBug01',
#  'GWCAAquBug02',
#  'GWCAAquBug03',
#  'HEHOAqubug01',
#  'HOSPAqubug01',
#  'HOSPAqubug02',
#  'OZARRMINVECM01',
#  'OZARRMINVECM02',
#  'OZARRMINVECM03',
#  'OZARRMINVECM06',
#  'OZARRMINVECT01',
#  'OZARRMINVECT02',
#  'OZARRMINVECT03',
#  'OZARRMINVECT04',
#  'OZARRMINVECT06',
#  'OZARRMINVECT07',
#  'OZARRMINVECT08',
#  'OZARRMINVECT09',
#  'OZARRMINVECT12',
#  'OZARRMINVECT13',
#  'OZARRMINVECT14',
#  'OZARRMINVECT15',
#  'OZARRMINVECT16',
#  'OZARRMINVEJM01',
#  'OZARRMINVEJM02',
#  'OZARRMINVEJM03',
#  'OZARRMINVEJT01',
#  'OZARRMINVEJT02',
#  'OZARRMINVEJT03',
#  'PERIAQUBUG01',
#  'PERIAQUBUG02',
#  'PERIAQUBUG03',
#  'PERIAqubug01',
#  'PERIAqubug02',
#  'PERIAqubug03',
#  'PIPEAquBug01',
#  'TAPRAqubug01',
#  'TAPRAqubug02',
#  'WICRAQUBUG02',
#  'WICRAQUBUG03',
#  'WICRAQUBUG04',
#  'WICRAquBug01',
#  'WICRAquBug02',
#  'WICRAquBug03']

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMINVE2005DEC01',
#  'BUFFRMINVE2005DEC14',
#  'BUFFRMINVE2005DEC20',
#  'BUFFRMINVE2005NOV29',
#  'BUFFRMINVE2005NOV30',
#  'BUFFRMINVE2007Dec03',
#  'BUFFRMINVE2007Dec04',
#  'BUFFRMINVE2007FEB09',
#  'BUFFRMINVE2007FEB20',
#  'BUFFRMINVE2007FEB21',
#  'BUFFRMINVE2007JAN04',
#  'BUFFRMINVE2007JAN05',
#  'BUFFRMINVE2007JAN08',
#  'BUFFRMINVE2007JAN09',
#  'BUFFRMINVE2007Nov26',
#  'BUFFRMINVE2007Nov27',
#  'BUFFRMINVE2007Nov28',
#  'BUFFRMINVE2007Nov29',
#  'BUFFRMINVE2007Nov30',
#  'BUFFRMINVE2008Dec02',
#  'BUFFRMINVE2008Dec03',
#  'BUFFRMINVE2008Dec04',
#  'BUFFRMINVE2008Dec05',
#  'BUFFRMINVE2008Dec10',
#  'BUFFRMINVE2008Dec11',
#  'BUFFRMINVE2008Jan22',
#  'BUFFRMINVE2008Jan23',
#  'BUFFRMINVE2009Dec07',
#  'BUFFRMINVE2009Dec08',
#  'BUFFRMINVE2009Dec14',
#  'BUFFRMINVE2009Dec15',
#  'BUFFRMINVE2009Dec16',
#  'BUFFRMINVE2009Feb18',
#  'BUFFRMINVE2009Jan08',
#  'BUFFRMINVE2010Dec01',
#  'BUFFRMINVE2010Jan11',
#  'BUFFRMINVE2010Jan12',
#  'BUFFRMINVE2010Jan14',
#  'BUFFRMINVE2010Jan15',
#  'BUFFRMINVE2010Jan21',
#  'BUFFRMINVE2010Nov29',
#  'BUFFRMINVE2010Nov30',
#  'BUFFRMINVE2011Dec01',
#  'BUFFRMINVE2011Dec07',
#  'BUFFRMINVE2011Dec28',
#  'BUFFRMINVE2012Jan04',
#  'BUFFRMINVE2013Nov21',
#  'BUFFRMINVE2014Jan23',
#  'BUFFRMINVE2014Jan24',
#  'BUFFRMINVE2014Jan30',
#  'BUFFRMINVE2015Dec07',
#  'BUFFRMINVE2015Dec08',
#  'BUFFRMINVE2015Nov23',
#  'BUFFRMINVE2015Nov24',
#  'BUFFRMINVE2017Dec04',
#  'BUFFRMINVE2017Nov15',
#  'BUFFRMINVE2017Nov29',
#  'BUFFRMINVE2017Nov30',
#  'BUFFRMINVE2019Nov04',
#  'BUFFRMINVE2019Nov05',
#  'BUFFRMINVE2019Nov06',
#  'BUFFRMINVE2019Nov19',
#  'BUFFRMINVE2021Nov02',
#  'BUFFRMINVE2021Nov03',
#  'BUFFRMINVE2021Nov04',
#  'BUFFRMINVE2021Nov09',
#  'BUFFRMINVE2021Nov10',
#  'BUFFRMINVE2023Nov01',
#  'BUFFRMINVE2023Nov03',
#  'BUFFRMINVE2023Nov06',
#  'BUFFRMINVE2023Nov14',
#  'EFMOAquBug2014Aug13',
#  'EFMOAquBug2017Jul18',
#  'EFMOAqubug2008Jul09',
#  'GWCAAquBug2016May02',
#  'GWCAAquBug2019May06',
#  'GWCAAquBug2022May02',
#  'GWCAAqubug2006Jun27',
#  'GWCAAqubug2007Jun26',
#  'GWCAAqubug2010May05',
#  'GWCAAqubug2013May01',
#  'HEHOAquBug2017Jul17',
#  'HEHOAquBug2021Jul26',
#  'HEHOAquBug2022Jul05',
#  'HEHOAquBug2023Jul17',
#  'HOSPAquBug2015Jul07',
#  'HOSPAquBug2018Jul09',
#  'HOSPAquBug2024Jul16',
#  'HOSPAquBug2024Jul17',
#  'HOSPAqubug2009Jun16',
#  'HOSPAqubug2009Jun17',
#  'HOSPAqubug2012Jul10',
#  'OZARRMINVE2006DEC12',
#  'OZARRMINVE2006DEC13',
#  'OZARRMINVE2006DEC14',
#  'OZARRMINVE2006DEC18',
#  'OZARRMINVE2006DEC19',
#  'OZARRMINVE2006DEC22',
#  'OZARRMINVE2006JAN03',
#  'OZARRMINVE2006JAN04',
#  'OZARRMINVE2006JAN05',
#  'OZARRMINVE2006JAN10',
#  'OZARRMINVE2006JAN11',
#  'OZARRMINVE2006JAN12',
#  'OZARRMINVE2006JAN20',
#  'OZARRMINVE2006NOV15',
#  'OZARRMINVE2007Nov01',
#  'OZARRMINVE2007Nov06',
#  'OZARRMINVE2007Nov07',
#  'OZARRMINVE2007Nov08',
#  'OZARRMINVE2007Nov09',
#  'OZARRMINVE2007Nov13',
#  'OZARRMINVE2007Nov14',
#  'OZARRMINVE2008Nov06',
#  'OZARRMINVE2008Nov07',
#  'OZARRMINVE2008Nov12',
#  'OZARRMINVE2008Nov13',
#  'OZARRMINVE2008Nov21',
#  'OZARRMINVE2009Nov06',
#  'OZARRMINVE2009Nov09',
#  'OZARRMINVE2009Nov10',
#  'OZARRMINVE2009Nov12',
#  'OZARRMINVE2009Nov24',
#  'OZARRMINVE2010Nov03',
#  'OZARRMINVE2010Nov04',
#  'OZARRMINVE2012Nov13',
#  'OZARRMINVE2012Nov14',
#  'OZARRMINVE2012Nov15',
#  'OZARRMINVE2014Nov06',
#  'OZARRMINVE2014Nov07',
#  'OZARRMINVE2014Nov12',
#  'OZARRMINVE2016Nov02',
#  'OZARRMINVE2016Nov03',
#  'OZARRMINVE2016Nov09',
#  'OZARRMINVE2018Nov08',
#  'OZARRMINVE2018Nov09',
#  'OZARRMINVE2018Nov19',
#  'OZARRMINVE2020Dec01',
#  'OZARRMINVE2020Nov17',
#  'OZARRMINVE2021Jan05',
#  'OZARRMINVE2021Jan14',
#  'OZARRMINVE2022Oct25',
#  'OZARRMINVE2022Oct26',
#  'OZARRMINVE2022Oct28',
#  'PERIAquBug2015May05',
#  'PERIAquBug2018May07',
#  'PERIAquBug2021May06',
#  'PERIAquBug2021May10',
#  'PERIAqubug2009May01',
#  'PERIAqubug2009May04',
#  'PERIAqubug2010May12',
#  'PERIAqubug2012May01',
#  'PERIAqubug2024May15',
#  'PIPEAquBug2013Sep12',
#  'PIPEAquBug2016Sep09',
#  'PIPEAquBug2021Aug26',
#  'PIPEAquBug2022Aug18',
#  'PIPEAqubug2007Aug28',
#  'TAPRAquBug2015Apr29',
#  'TAPRAquBug2018May04',
#  'TAPRAqubug2009Sep01',
#  'TAPRAqubug2009Sep02',
#  'TAPRAqubug2013Apr23',
#  'TAPRAqubug2024May07',
#  'WICRAquBug2016May04',
#  'WICRAquBug2019Jun03',
#  'WICRAquBug2019Jun11',
#  'WICRAquBug2022Jun02',
#  'WICRAquBug2022Jun09',
#  'WICRAquBug2022Jun14',
#  'WICRAqubug2006Jun13',
#  'WICRAqubug2006Jun14',
#  'WICRAqubug2007Jul15',
#  'WICRAqubug2007Jun22',
#  'WICRAqubug2010May03',
#  'WICRAqubug2013May06']

# %%
sorted(df['Units'].unique())
# Out:
# ['meters']

# %%
sorted(df['DischargeNo'].unique())
# Out:
# [np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(18),
#  np.int64(19),
#  np.int64(20),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31)]

# %%
plt.hist(df['DischargeNo'], bins=10, edgecolor='black')
plt.title('Histogram of DischargeNo')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_DistFromBank'] = df.loc[df['DistanceFromBank_m'] >= 0, 'DistanceFromBank_m']

# %%
plt.hist(df['filtered_DistFromBank'], bins=10, edgecolor='black')
plt.title('Histogram of filtered_DistFromBank')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Depth_cm'] = df.loc[df['Depth_cm'] >= 0, 'Depth_cm']

# %%
plt.hist(df['filtered_Depth_cm'], bins=10, edgecolor='black')
plt.title('Histogram of filtered_Depth_cm')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Velocity_ms'] = df.loc[df['Velocity_ms'] >= 0, 'Velocity_ms']

# %%
plt.hist(df['filtered_Velocity_ms'], bins=10, edgecolor='black')
plt.title('Histogram of filtered_Velocity_ms')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['Comments'] = df['Comments'].astype(str)

# %%
sorted(df['Comments'].unique())
# Out:
# [' ',
#  '*',
#  '0',
#  '0.5',
#  'Boulder',
#  'No discharge taken, too low for meaningful results',
#  'SHORT',
#  'big boulder moved to left',
#  'boulder in front of first point',
#  'half meter',
#  'moved over due to grass patch',
#  'nan',
#  'no discharge - Dead flow meter',
#  'short distance',
#  'taken within watercress',
#  'to shallow',
#  'tree roots creating on bank eddie',
#  'veg up',
#  'very little flow, negative reading']

# %%
# Omitted DETimeStamp in the QC review
