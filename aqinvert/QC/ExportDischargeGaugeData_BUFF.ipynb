# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("ExportDischargeGaugeData_BUFF.csv")
df
# Out:
#                   ParkName ParkCode  Season      LocationID  \
# 0   Buffalo National River     BUFF    2006  BUFFRMINVEBM05
# 1   Buffalo National River     BUFF    2011  BUFFRMINVEBM01
# 2   Buffalo National River     BUFF    2011  BUFFRMINVEBM02
# 3   Buffalo National River     BUFF    2011  BUFFRMINVEBM03
# 4   Buffalo National River     BUFF    2011  BUFFRMINVEBM04
# 5   Buffalo National River     BUFF    2011  BUFFRMINVEBM05
# 6   Buffalo National River     BUFF    2011  BUFFRMINVEBM06
# 7   Buffalo National River     BUFF    2011  BUFFRMINVEBT20
# 8   Buffalo National River     BUFF    2013  BUFFRMINVEBM03
# 9   Buffalo National River     BUFF    2013  BUFFRMINVEBM04
# 10  Buffalo National River     BUFF    2013  BUFFRMINVEBT20
# 11  Buffalo National River     BUFF    2015  BUFFRMINVEBM01
# 12  Buffalo National River     BUFF    2015  BUFFRMINVEBM02
# 13  Buffalo National River     BUFF    2015  BUFFRMINVEBM03
# 14  Buffalo National River     BUFF    2015  BUFFRMINVEBM03
# 15  Buffalo National River     BUFF    2015  BUFFRMINVEBM04
# 16  Buffalo National River     BUFF    2015  BUFFRMINVEBM05
# 17  Buffalo National River     BUFF    2015  BUFFRMINVEBM06
# 18  Buffalo National River     BUFF    2015  BUFFRMINVEBT13
# 19  Buffalo National River     BUFF    2015  BUFFRMINVEBT20
# 20  Buffalo National River     BUFF    2017  BUFFRMINVEBM02
# 21  Buffalo National River     BUFF    2017  BUFFRMINVEBM03
# 22  Buffalo National River     BUFF    2017  BUFFRMINVEBM04
# 23  Buffalo National River     BUFF    2017  BUFFRMINVEBM05
# 24  Buffalo National River     BUFF    2017  BUFFRMINVEBM06
# 25  Buffalo National River     BUFF    2017  BUFFRMINVEBT20
# 26  Buffalo National River     BUFF    2019  BUFFRMINVEBM01
# 27  Buffalo National River     BUFF    2019  BUFFRMINVEBM02
# 28  Buffalo National River     BUFF    2019  BUFFRMINVEBM03
# 29  Buffalo National River     BUFF    2019  BUFFRMINVEBM04
# 30  Buffalo National River     BUFF    2019  BUFFRMINVEBM05
# 31  Buffalo National River     BUFF    2019  BUFFRMINVEBM06
# 32  Buffalo National River     BUFF    2019  BUFFRMINVEBT20
# 33  Buffalo National River     BUFF    2021  BUFFRMINVEBM01
# 34  Buffalo National River     BUFF    2021  BUFFRMINVEBM02
# 35  Buffalo National River     BUFF    2021  BUFFRMINVEBM03
# 36  Buffalo National River     BUFF    2021  BUFFRMINVEBM04
# 37  Buffalo National River     BUFF    2021  BUFFRMINVEBM05
# 38  Buffalo National River     BUFF    2021  BUFFRMINVEBM06
# 39  Buffalo National River     BUFF    2021  BUFFRMINVEBT20
# 40  Buffalo National River     BUFF    2023  BUFFRMINVEBM01
# 41  Buffalo National River     BUFF    2023  BUFFRMINVEBM02
# 42  Buffalo National River     BUFF    2023  BUFFRMINVEBM03
# 43  Buffalo National River     BUFF    2023  BUFFRMINVEBM04
# 44  Buffalo National River     BUFF    2023  BUFFRMINVEBM05
# 45  Buffalo National River     BUFF    2023  BUFFRMINVEBM06
# 46  Buffalo National River     BUFF    2023  BUFFRMINVEBT20
#
#                 EventID   Units  GaugeSiteNo  \
# 0   BUFFRMINVE2007FEB22  meters      7056000
# 1   BUFFRMINVE2012Jan05  meters      7055646
# 2   BUFFRMINVE2012Jan06  meters      7055680
# 3   BUFFRMINVE2012Jan09  meters      7055680
# 4   BUFFRMINVE2012Jan04  meters      7056000
# 5   BUFFRMINVE2012Jan10  meters      7056000
# 6   BUFFRMINVE2012Jan18  meters      7056700
# 7   BUFFRMINVE2012Jan05  meters      7056515
# 8   BUFFRMINVE2014Feb19  meters      7055680
# 9   BUFFRMINVE2013Dec04  meters      7056000
# 10  BUFFRMINVE2013Dec04  meters      7056515
# 11  BUFFRMINVE2015Dec17  meters      7055646
# 12  BUFFRMINVE2015Dec18  meters      7055680
# 13  BUFFRMINVE2015Dec18  meters      7055680
# 14  BUFFRMINVE2015Dec18  meters     14111470
# 15  BUFFRMINVE2015Nov24  meters      7056000
# 16  BUFFRMINVE2015Dec17  meters      7056000
# 17  BUFFRMINVE2015Dec09  meters      7056700
# 18  BUFFRMINVE2015Nov23  meters      7055790
# 19  BUFFRMINVE2015Nov24  meters      7056515
# 20  BUFFRMINVE2017Nov29  meters      7055680
# 21  BUFFRMINVE2017Dec01  meters      7055680
# 22  BUFFRMINVE2017Nov16  meters      7056000
# 23  BUFFRMINVE2017Nov30  meters      7056000
# 24  BUFFRMINVE2017Dec08  meters      7056700
# 25  BUFFRMINVE2017Nov16  meters      7056515
# 26  BUFFRMINVE2019Nov18  meters      7055646
# 27  BUFFRMINVE2019Nov20  meters      7055680
# 28  BUFFRMINVE2019Nov20  meters      7055680
# 29  BUFFRMINVE2019Nov18  meters      7056000
# 30  BUFFRMINVE2019Nov21  meters      7056000
# 31  BUFFRMINVE2019Nov19  meters      7056700
# 32  BUFFRMINVE2019Nov05  meters      7056515
# 33  BUFFRMINVE2021Nov10  meters      7055646
# 34  BUFFRMINVE2021Nov09  meters      7055680
# 35  BUFFRMINVE2021Nov08  meters      7055680
# 36  BUFFRMINVE2021Nov03  meters      7056000
# 37  BUFFRMINVE2021Nov02  meters      7056000
# 38  BUFFRMINVE2021Nov01  meters      7056700
# 39  BUFFRMINVE2021Nov03  meters      7056515
# 40  BUFFRMINVE2023Nov14  meters      7055646
# 41  BUFFRMINVE2023Nov02  meters      7055680
# 42  BUFFRMINVE2023Nov02  meters      7055680
# 43  BUFFRMINVE2023Nov03  meters      7056000
# 44  BUFFRMINVE2023Nov07  meters      7056000
# 45  BUFFRMINVE2023Nov08  meters      7056700
# 46  BUFFRMINVE2023Nov06  meters      7056515
#
#                                         GaugeLocation  Discharge_cms  \
# 0                      Buffalo River near St. Joe, AR          32.28
# 1                       Buffalo River near Boxley, AR           1.16
# 2                         Buffalo River at Pruitt, AR           1.86
# 3                         Buffalo River at Pruitt, AR           1.44
# 4                      Buffalo River near St. Joe, AR          25.71
# 5                      Buffalo River near St. Joe, AR          51.82
# 6                      Buffalo River near Harriet, AR          24.49
# 7                     Bear Creek near Silver Hill, AR           0.05
# 8                         Buffalo River at Pruitt, AR           3.28
# 9                      Buffalo River near St. Joe, AR           4.44
# 22                                                NaN  10/8/2020 15:29
# 23                                                NaN  10/8/2020 15:29
# 24                                                NaN  10/8/2020 15:29
# 25                                                NaN  10/8/2020 15:29
# 26                                                NaN  10/8/2020 15:29
# 27                                                NaN  10/8/2020 15:29
# 28    Pruitt only; Big Cr guage no longer taking data  10/8/2020 15:29
# 29                                                NaN  10/8/2020 15:29
# 30                                                NaN  10/8/2020 15:29
# 31                                                NaN  10/8/2020 15:29
# 32                                                NaN  10/8/2020 15:29
# 33                                                NaN    3/6/2023 8:20
# 34                                                NaN   3/6/2023 14:24
# 35  Pruitt guage only; Big Cr guage no longer coll...    3/7/2023 7:33
# 36                                                NaN    3/7/2023 8:14
# 37                                                NaN    3/7/2023 9:19
# 38                                                NaN    3/7/2023 9:25
# 39                                                NaN   3/7/2023 13:05
# 40                                                NaN    3/8/2024 8:21
# 41                                                NaN   3/8/2024 10:02
# 42                                                NaN   3/8/2024 11:14
# 43                                                NaN   3/8/2024 12:36
# 44                                                NaN  3/28/2024 12:18
# 45                                                NaN  3/28/2024 14:09
# 46                                                NaN   3/11/2024 9:33

# %%
df.dtypes
# Out:
# ParkName          object
# ParkCode          object
# Season             int64
# LocationID        object
# EventID           object
# Units             object
# GaugeSiteNo        int64
# GaugeLocation     object
# Discharge_cms    float64
# Comments          object
# DETimeStamp       object
# dtype: object

# %%
sorted(df['ParkName'].unique())
# Out:
# ['Buffalo National River']

# %%
frequency = df['ParkName'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
sorted(df['ParkCode'].unique())
# Out:
# ['BUFF']

# %%
frequency = df['ParkCode'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
sorted(df['Season'].unique())
# Out:
# [np.int64(2006),
#  np.int64(2011),
#  np.int64(2013),
#  np.int64(2015),
#  np.int64(2017),
#  np.int64(2019),
#  np.int64(2021),
#  np.int64(2023)]

# %%
plt.hist(df['Season'], bins=5, edgecolor='black')
plt.title('Histogram of Season')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['LocationID'].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT20']

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMINVE2007FEB22',
#  'BUFFRMINVE2012Jan04',
#  'BUFFRMINVE2012Jan05',
#  'BUFFRMINVE2012Jan06',
#  'BUFFRMINVE2012Jan09',
#  'BUFFRMINVE2012Jan10',
#  'BUFFRMINVE2012Jan18',
#  'BUFFRMINVE2013Dec04',
#  'BUFFRMINVE2014Feb19',
#  'BUFFRMINVE2015Dec09',
#  'BUFFRMINVE2015Dec17',
#  'BUFFRMINVE2015Dec18',
#  'BUFFRMINVE2015Nov23',
#  'BUFFRMINVE2015Nov24',
#  'BUFFRMINVE2017Dec01',
#  'BUFFRMINVE2017Dec08',
#  'BUFFRMINVE2017Nov16',
#  'BUFFRMINVE2017Nov29',
#  'BUFFRMINVE2017Nov30',
#  'BUFFRMINVE2019Nov05',
#  'BUFFRMINVE2019Nov18',
#  'BUFFRMINVE2019Nov19',
#  'BUFFRMINVE2019Nov20',
#  'BUFFRMINVE2019Nov21',
#  'BUFFRMINVE2021Nov01',
#  'BUFFRMINVE2021Nov02',
#  'BUFFRMINVE2021Nov03',
#  'BUFFRMINVE2021Nov08',
#  'BUFFRMINVE2021Nov09',
#  'BUFFRMINVE2021Nov10',
#  'BUFFRMINVE2023Nov02',
#  'BUFFRMINVE2023Nov03',
#  'BUFFRMINVE2023Nov06',
#  'BUFFRMINVE2023Nov07',
#  'BUFFRMINVE2023Nov08',
#  'BUFFRMINVE2023Nov14']

# %%
sorted(df['Units'].unique())
# Out:
# ['meters']

# %%
sorted(df['GaugeSiteNo'].unique())
# Out:
# [np.int64(7055646),
#  np.int64(7055680),
#  np.int64(7055790),
#  np.int64(7056000),
#  np.int64(7056515),
#  np.int64(7056700),
#  np.int64(14111470)]

# %%
plt.hist(df['GaugeSiteNo'], bins=10, edgecolor='black')
plt.title('Histogram of GaugeSiteNo')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['GaugeLocation'].unique())
# Out:
# ['Bear Creek near Silver Hill, AR',
#  'Big Creek near Mt. Judea, AR',
#  'Buffalo River at Pruitt + Big Creek near Mt. Judea AR',
#  'Buffalo River at Pruitt, AR',
#  'Buffalo River near Boxley, AR',
#  'Buffalo River near Harriet, AR',
#  'Buffalo River near St. Joe, AR']

# %%
plt.hist(df['Discharge_cms'], bins=10, edgecolor='black')
plt.title('Histogram of Discharge_cms')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['Comments'] = df['Comments'].astype(str)

# %%
sorted(df['Comments'].unique())
# Out:
# ['11.92 (Pruitt) + 0.17 (Big Creek)',
#  'BM03 2015 also entered as Pruitt (11.92) guage + Big Cr (0.17) guage',
#  'Bear Creek USGS gauge',
#  'Pruitt USGS gauge, Carver gauge = 6.7ft',
#  'Pruitt guage only; Big Cr guage no longer collecting data',
#  'Pruitt only; Big Cr guage no longer taking data',
#  'Pruitt only; Big Cr guage no longer taking discharge',
#  'St. Joe USGS gauge',
#  'cms - Bear Creek USGS gauge',
#  'cms - Boxley USGS gauge',
#  'cms - Harriett USGS gauge',
#  'cms - Pruitt USGS gauge',
#  'cms - St. Joe USGS gauge',
#  'nan']

# %%
# Omitted DETimeStamp in the QC review
