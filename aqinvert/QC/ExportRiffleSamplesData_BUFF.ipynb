# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("ExportRiffleSamplesData_BUFF.csv")
df
# Out:
#                     ParkName ParkCode  Season      LocationID  \
# 0     Buffalo National River     BUFF    2005  BUFFRMINVEBM02
# 1     Buffalo National River     BUFF    2005  BUFFRMINVEBM02
# 2     Buffalo National River     BUFF    2005  BUFFRMINVEBM02
# 3     Buffalo National River     BUFF    2005  BUFFRMINVEBM02
# 4     Buffalo National River     BUFF    2005  BUFFRMINVEBM02
# ...                      ...      ...     ...             ...
# 1261  Buffalo National River     BUFF    2023  BUFFRMINVEBT27
# 1262  Buffalo National River     BUFF    2023  BUFFRMINVEBT27
# 1263  Buffalo National River     BUFF    2023  BUFFRMINVEBT27
# 1264  Buffalo National River     BUFF    2023  BUFFRMINVEBT27
# 1265  Buffalo National River     BUFF    2023  BUFFRMINVEBT27
#
#                   EventID  RiffleNo Replicate  Width  Depth  Velocity  ...  \
# 0     BUFFRMINVE2005NOV29         1         L    7.6   17.0      0.60  ...
# 1     BUFFRMINVE2005NOV29         1         M    7.8   22.0      1.16  ...
# 2     BUFFRMINVE2005NOV29         1         R   10.8   10.0      0.50  ...
# 3     BUFFRMINVE2005NOV29         2         L   11.6   14.0      0.51  ...
# 4     BUFFRMINVE2005NOV29         2         M   12.5    9.0      0.26  ...
# ...                   ...       ...       ...    ...    ...       ...  ...
# 1261  BUFFRMINVE2023Nov03         2         M -999.0   16.0      0.27  ...
# 1262  BUFFRMINVE2023Nov03         2         R -999.0   24.0      0.30  ...
# 1263  BUFFRMINVE2023Nov03         3         L -999.0   12.0      0.24  ...
# 1264  BUFFRMINVE2023Nov03         3         M -999.0   16.0      0.24  ...
# 1265  BUFFRMINVE2023Nov03         3         R -999.0   10.0      0.28  ...
#
#       Vegetation%  Algae  Algae%  Periphyton  Periphyton%  Deposition  \
# 0             0.0    0.0     0.0         2.0         25.0         1.0
# 1             0.0    1.0     5.0         2.0         25.0         1.0
# 2             0.0    0.0     0.0         2.0         25.0         1.0
# 3             0.0    0.0     0.0         2.0         25.0         1.0
# 4             0.0    0.0     0.0         2.0         25.0         1.0
# ...           ...    ...     ...         ...          ...         ...
# 1261          0.0    0.0     0.0         1.0          5.0      -999.0
# 1262          0.0    0.0     0.0         2.0         25.0      -999.0
# 1263          0.0    0.0     0.0         1.0          5.0      -999.0
# 1264          0.0    0.0     0.0         2.0         25.0      -999.0
# 1265          0.0    0.0     0.0         2.0         25.0      -999.0
#
#       Deposition%  Organics  Organics%         DETimeStamp
# 0             5.0       3.0       57.5  10/5/2020 11:45:57
# 1             5.0       2.0       25.0  10/5/2020 11:45:57
# 2             5.0       2.0       25.0  10/5/2020 11:45:57
# 3             5.0       2.0       25.0  10/5/2020 11:45:57
# 4             5.0       2.0       25.0  10/5/2020 11:45:57
# ...           ...       ...        ...                 ...
# 1261       -999.0    -999.0     -999.0   4/4/2024 11:26:09
# 1262       -999.0    -999.0     -999.0   4/4/2024 11:26:24
# 1263       -999.0    -999.0     -999.0   4/4/2024 11:25:20
# 1264       -999.0    -999.0     -999.0   4/4/2024 11:25:31
# 1265       -999.0    -999.0     -999.0   4/4/2024 11:25:45
#
# [1266 rows x 25 columns]

# %%
df.dtypes
# Out:
# ParkName          object
# ParkCode          object
# Season             int64
# LocationID        object
# EventID           object
# RiffleNo           int64
# Replicate         object
# Width            float64
# Depth            float64
# Velocity         float64
# Substrate        float64
# Substrate_mm     float64
# Embeddedness     float64
# Embeddedness%    float64
# Vegetation       float64
# Vegetation%      float64
# Algae            float64
# Algae%           float64
# Periphyton       float64
# Periphyton%      float64
# Deposition       float64
# Deposition%      float64
# Organics         float64
# Organics%        float64
# DETimeStamp       object
# dtype: object

# %%
sorted(df['ParkName'].unique())
# Out:
# ['Buffalo National River']

# %%
frequency = df['ParkName'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
df['ParkCode'] = df['ParkCode'].astype(str)

# %%
sorted(df['ParkCode'].unique())
# Out:
# ['BUFF']

# %%
frequency = df['ParkCode'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
sorted(df['Season'].unique())
# Out:
# [np.int64(2005),
#  np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2013),
#  np.int64(2015),
#  np.int64(2017),
#  np.int64(2019),
#  np.int64(2021),
#  np.int64(2023)]

# %%
plt.hist(df['Season'], bins=5, edgecolor='black')
plt.title('Histogram of Season')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['LocationID'].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT01',
#  'BUFFRMINVEBT03',
#  'BUFFRMINVEBT04',
#  'BUFFRMINVEBT05',
#  'BUFFRMINVEBT06',
#  'BUFFRMINVEBT07',
#  'BUFFRMINVEBT08',
#  'BUFFRMINVEBT09',
#  'BUFFRMINVEBT10',
#  'BUFFRMINVEBT11',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT14',
#  'BUFFRMINVEBT15',
#  'BUFFRMINVEBT16',
#  'BUFFRMINVEBT17',
#  'BUFFRMINVEBT19',
#  'BUFFRMINVEBT20',
#  'BUFFRMINVEBT22',
#  'BUFFRMINVEBT23',
#  'BUFFRMINVEBT24',
#  'BUFFRMINVEBT25',
#  'BUFFRMINVEBT27',
#  'BUFFRMINVEBT30',
#  'BUFFRMINVEBT31',
#  'BUFFRMINVEBT33']

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMINVE2005DEC01',
#  'BUFFRMINVE2005DEC14',
#  'BUFFRMINVE2005DEC20',
#  'BUFFRMINVE2005NOV29',
#  'BUFFRMINVE2005NOV30',
#  'BUFFRMINVE2007Dec03',
#  'BUFFRMINVE2007Dec04',
#  'BUFFRMINVE2007FEB09',
#  'BUFFRMINVE2007FEB20',
#  'BUFFRMINVE2007FEB21',
#  'BUFFRMINVE2007FEB22',
#  'BUFFRMINVE2007JAN04',
#  'BUFFRMINVE2007JAN05',
#  'BUFFRMINVE2007JAN08',
#  'BUFFRMINVE2007JAN09',
#  'BUFFRMINVE2007Nov26',
#  'BUFFRMINVE2007Nov27',
#  'BUFFRMINVE2007Nov28',
#  'BUFFRMINVE2007Nov29',
#  'BUFFRMINVE2007Nov30',
#  'BUFFRMINVE2008Dec02',
#  'BUFFRMINVE2008Dec03',
#  'BUFFRMINVE2008Dec04',
#  'BUFFRMINVE2008Dec05',
#  'BUFFRMINVE2008Dec10',
#  'BUFFRMINVE2008Dec11',
#  'BUFFRMINVE2008Jan22',
#  'BUFFRMINVE2008Jan23',
#  'BUFFRMINVE2009Dec07',
#  'BUFFRMINVE2009Dec08',
#  'BUFFRMINVE2009Dec14',
#  'BUFFRMINVE2009Dec15',
#  'BUFFRMINVE2009Dec16',
#  'BUFFRMINVE2009Feb18',
#  'BUFFRMINVE2009Jan08',
#  'BUFFRMINVE2010Dec01',
#  'BUFFRMINVE2010Jan11',
#  'BUFFRMINVE2010Jan12',
#  'BUFFRMINVE2010Jan14',
#  'BUFFRMINVE2010Jan15',
#  'BUFFRMINVE2010Jan21',
#  'BUFFRMINVE2010Nov29',
#  'BUFFRMINVE2010Nov30',
#  'BUFFRMINVE2011Dec01',
#  'BUFFRMINVE2011Dec07',
#  'BUFFRMINVE2011Dec28',
#  'BUFFRMINVE2012Jan04',
#  'BUFFRMINVE2012Jan05',
#  'BUFFRMINVE2012Jan06',
#  'BUFFRMINVE2012Jan09',
#  'BUFFRMINVE2012Jan10',
#  'BUFFRMINVE2012Jan18',
#  'BUFFRMINVE2013Dec04',
#  'BUFFRMINVE2013Nov21',
#  'BUFFRMINVE2014Feb19',
#  'BUFFRMINVE2014Jan23',
#  'BUFFRMINVE2014Jan24',
#  'BUFFRMINVE2014Jan29',
#  'BUFFRMINVE2014Jan30',
#  'BUFFRMINVE2014Jan31',
#  'BUFFRMINVE2015Dec07',
#  'BUFFRMINVE2015Dec08',
#  'BUFFRMINVE2015Dec09',
#  'BUFFRMINVE2015Dec17',
#  'BUFFRMINVE2015Dec18',
#  'BUFFRMINVE2015Nov23',
#  'BUFFRMINVE2015Nov24',
#  'BUFFRMINVE2017Dec01',
#  'BUFFRMINVE2017Dec04',
#  'BUFFRMINVE2017Dec08',
#  'BUFFRMINVE2017Nov15',
#  'BUFFRMINVE2017Nov16',
#  'BUFFRMINVE2017Nov29',
#  'BUFFRMINVE2017Nov30',
#  'BUFFRMINVE2019Nov04',
#  'BUFFRMINVE2019Nov05',
#  'BUFFRMINVE2019Nov06',
#  'BUFFRMINVE2019Nov18',
#  'BUFFRMINVE2019Nov19',
#  'BUFFRMINVE2019Nov20',
#  'BUFFRMINVE2019Nov21',
#  'BUFFRMINVE2021Nov01',
#  'BUFFRMINVE2021Nov02',
#  'BUFFRMINVE2021Nov03',
#  'BUFFRMINVE2021Nov04',
#  'BUFFRMINVE2021Nov08',
#  'BUFFRMINVE2021Nov09',
#  'BUFFRMINVE2021Nov10',
#  'BUFFRMINVE2023Nov01',
#  'BUFFRMINVE2023Nov02',
#  'BUFFRMINVE2023Nov03',
#  'BUFFRMINVE2023Nov06',
#  'BUFFRMINVE2023Nov07',
#  'BUFFRMINVE2023Nov08',
#  'BUFFRMINVE2023Nov14']

# %%
sorted(df['RiffleNo'].unique())
# Out:
# [np.int64(1), np.int64(2), np.int64(3)]

# %%
plt.hist(df['RiffleNo'], bins=10, edgecolor='black')
plt.title('Histogram of RiffleNo')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['Replicate'].unique())
# Out:
# ['L', 'M', 'R']

# %%
frequency = df['Replicate'].value_counts()

# Plot the bar chart with increased spacing
fig, ax = plt.subplots()
bar_width = 0.5  # Reduce the width of the bars
bars = ax.bar(frequency.index, frequency.values, width=bar_width, color=['blue', 'green', 'red', 'purple', 'orange'])
ax.set_title('Frequency of Categories')
ax.set_xlabel('Category')
ax.set_ylabel('Frequency')

# Add some padding between bars
ax.set_xticks(range(len(frequency)))
ax.set_xticklabels(frequency.index, rotation=45, ha='right')

# Show plot with the adjusted layout
plt.tight_layout()
plt.show()

# %%
df['filtered_Width'] = df.loc[df['Width'] >= 0, 'Width']

# %%
plt.hist(df['filtered_Width'], bins=5, edgecolor='black')
plt.title('Histogram of Width')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Depth'] = df.loc[df['Depth'] >= 0, 'Depth']

# %%
plt.hist(df['filtered_Depth'], bins=5, edgecolor='black')
plt.title('Histogram of Depth')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Velocity'] = df.loc[df['Velocity'] >= 0, 'Velocity']

# %%
plt.hist(df['filtered_Velocity'], bins=5, edgecolor='black')
plt.title('Histogram of Velocity')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Substrate'], bins=5, edgecolor='black')
plt.title('Histogram of Substrate')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Substrate_mm'], bins=5, edgecolor='black')
plt.title('Histogram of Substrate_mm')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Substrate_mm'] = df.loc[(df['Substrate_mm'] > 0) & (df['Substrate_mm'] < 2000), 'Substrate_mm']

# %%
plt.hist(df['filtered_Substrate_mm'], bins=50, edgecolor='black')
plt.title('Histogram of Substrate_mm')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Embeddedness'], bins=50, edgecolor='black')
plt.title('Histogram of Embeddedness')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sorted(df['Embeddedness%'].unique())
# Out:
# [np.float64(5.0), np.float64(25.0), np.float64(57.5), np.float64(87.5)]

# %%
plt.hist(df['Embeddedness%'], bins=50, edgecolor='black')
plt.title('Histogram of Embeddedness%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Vegetation'], bins=50, edgecolor='black')
plt.title('Histogram of Vegetation')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Vegetation%'], bins=50, edgecolor='black')
plt.title('Histogram of Vegetation%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Algae'], bins=50, edgecolor='black')
plt.title('Histogram of Algae')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Algae%'], bins=50, edgecolor='black')
plt.title('Histogram of Algae%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Periphyton'], bins=50, edgecolor='black')
plt.title('Histogram of Periphyton')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Periphyton%'], bins=50, edgecolor='black')
plt.title('Histogram of Periphyton%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Deposition'] = df.loc[(df['Deposition'] > 0), 'Deposition']

# %%
plt.hist(df['filtered_Deposition'], bins=50, edgecolor='black')
plt.title('Histogram of Deposition')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Deposition%'] = df.loc[(df['Deposition%'] > 0), 'Deposition%']

# %%
plt.hist(df['filtered_Deposition%'], bins=50, edgecolor='black')
plt.title('Histogram of Deposition%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Organics'] = df.loc[(df['Organics'] > 0), 'Organics']

# %%
plt.hist(df['filtered_Organics'], bins=50, edgecolor='black')
plt.title('Histogram of Organics')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['filtered_Organics%'] = df.loc[(df['Organics%'] > 0), 'Organics%']

# %%
plt.hist(df['filtered_Organics%'], bins=50, edgecolor='black')
plt.title('Histogram of Organics%')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# Omitted DETimeStamp in the QC review
